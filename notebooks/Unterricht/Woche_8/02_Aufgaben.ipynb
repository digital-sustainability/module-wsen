# %% [markdown]
# # SW08 / KW45 - Aufgaben (OOP + BO/ERD)
#
# Die Aufgaben steigen langsam an:
# 1. Begriffe erkennen
# 2. Eine einfache Klasse vervollständigen
# 3. Ein Businessobjekt mit 1:n-Beziehung umsetzen
#
# Arbeite Schritt für Schritt. Führe nach jedem Schritt die Zelle aus.

# %% [markdown]
# ## Aufgabe 1 (geführt): Klasse, Objekt, Attribut, Methode erkennen
#
# ### Auftrag
# Schau dir den Code an und beantworte zuerst nur mit Worten:
# - Was ist die Klasse?
# - Was ist das Objekt?
# - Welche Zeile speichert ein Attribut?
# - Welche Zeile definiert eine Methode?
#
# ### Tipp
# Schreibe deine Antworten direkt in dein Notizheft oder als Kommentar in die Zelle.

# %%
class Kunde:
    def __init__(self, kunden_nr, name):
        self.kunden_nr = kunden_nr
        self.name = name

    def vorstellen(self):
        return f"Hallo, ich bin {self.name}."

kunde = Kunde(1001, "Mia Keller")
kunde.vorstellen()

# %% [markdown]
# ## Aufgabe 2 (teilweise geführt): Klasse `Produkt`
#
# ### Auftrag
# Erstelle eine Klasse `Produkt` mit:
# - Attributen `produkt_nr`, `name`, `preis`
# - Methode `kurzinfo()`, die einen kurzen Satz mit Name und Preis zurückgibt
#
# ### Hinweise
# - Nutze `__init__`, um die Attribute zu speichern.
# - Die Methode soll einen String mit `return` zurückgeben.
#
# ### Selbstcheck
# - Ein Produkt mit dem Namen `Maus` und dem Preis `50` soll eine passende Kurzinfo zurückgeben.

# %%
class Produkt:
    def __init__(self, produkt_nr, name, preis):
        # TODO: Attribute setzen
        pass

    def kurzinfo(self):
        # TODO: Satz mit Name und Preis zurueckgeben
        pass

produkt = Produkt(10, "Maus", 50)
produkt.kurzinfo()

# %% [markdown]
# ## Aufgabe 3 (Transfer): Businessobjekt und ERD in Code umsetzen
#
# ### Szenario
# Ein `Kunde` kann mehrere `Bestellung`-Objekte haben.
# Das ist im ERD eine 1:n-Beziehung.
#
# ### Auftrag
# 1. Erstelle die Klasse `Bestellung` mit `bestell_nr` und `betrag`.
# 2. Erstelle die Klasse `Kunde` mit `kunden_nr`, `name` und einer Liste `bestellungen`.
# 3. Erstelle die Methode `bestellung_hinzufuegen(bestellung)`.
# 4. Teste den Code mit mindestens zwei Bestellungen.
#
# ### Selbstcheck
# - `len(kunde.bestellungen)` ist 2.
# - Du kannst die Bestellnummern über die Liste ausgeben.

# %%
class Bestellung:
    # TODO
    pass

class Kunde:
    # TODO
    pass

kunde = Kunde(7, "Lina")
kunde.bestellung_hinzufuegen(Bestellung(9001, 120))
kunde.bestellung_hinzufuegen(Bestellung(9002, 35))

len(kunde.bestellungen)

# %% [markdown]
# ## Projektaufgabe: Rechnung als Businessobjekte
# Übertrage das Klassenkonzept jetzt ins Rechnungsprojekt.
#
# ### Auftrag
# - Definiere `Kunde`, `Artikel`, `Rechnungsposition` und `Rechnung`.
# - Speichere die fachlichen Daten in Attributen und Beziehungen über Referenzen bzw. Listen - **nicht** in Dictionaries.
# - Implementiere in `Rechnungsposition` die normale Methode `summe()`.
# - Implementiere in `Rechnung` die Methode `netto()`, die alle Positionssummen addiert.
# - Erzeuge Kunde 1, die Artikel 1001 und 1002 sowie eine Rechnung mit zwei Positionen.
# - Zeichne daneben das ERD mit den Beziehungen Kunde-Rechnung, Rechnung-Position und Position-Artikel.
#
# ### Selbstcheck
# - `position.summe()` liefert den Betrag einer Position.
# - `rechnung.netto()` liefert die Nettosumme.
# - `len(rechnung.positionen)` ist 2.

# %% [markdown]
# ## Abschluss-Check
# - [ ] Ich kann Klasse, Objekt, Attribut und Methode in einem Beispiel erkennen.
# - [ ] Ich kann eine einfache Klasse mit `__init__` schreiben.
# - [ ] Ich kann eine Methode mit Punkt-Notation aufrufen.
# - [ ] Ich kann eine 1:n-Beziehung mit einer Liste modellieren.
#
# Wenn etwas nicht klappt: erst die Fehlermeldung lesen, dann mit `print(...)` Zwischenschritte sichtbar machen.
