# %% [markdown]
# # SW10 / KW47 - Aufgaben: Lambdas und Rekursion
#
# ## Hinweise
#
# - Loese die Aufgaben in Reihenfolge.
# - Arbeite bei `lambda`-Aufgaben mit sehr kleinen Beispielen.
# - Pruefe bei Rekursion zuerst den Basisfall.
# - Teste jede Funktion sofort mit eigenen Beispielen.

# %% [markdown]
# ---
# ## 1. Lambda-Grundlagen
#
# ### 1.1 Lambda statt kurzer `def`
# Schreibe fuer jede Funktion eine `lambda`-Variante.
# Tipp: Die Funktion soll so kurz sein, dass sie direkt lesbar bleibt.

# %%
# a) def verdoppeln(x): return x * 2
# b) def ist_gerade(x): return x % 2 == 0
# c) def punktzahl(note): return note * 20

# TODO: Ersetze die drei Funktionskoerper durch lambda-Ausdruecke.

# %% [markdown]
# ### 1.2 Sortieren mit `key=lambda`
# Sortiere die Tuples `(name, punktzahl)` absteigend nach punktzahl.
# Tipp: `key` bekommt eine kleine Funktion, die den Sortierwert liefert.

# %%
resultate = [("Lea", 72), ("Noah", 88), ("Mia", 81), ("Jan", 88)]

# TODO: Verwende sorted(..., key=lambda ...).
# Die Sortierung soll absteigend nach der Punktzahl erfolgen.

# %% [markdown]
# ### 1.3 Filtern mit `lambda`
# Behalte nur Dateinamen mit Endung `.txt`.
# Tipp: Die Funktion soll True oder False zurueckgeben.

# %%
dateien = ["daten.csv", "notiz.txt", "bild.png", "todo.txt", "main.py"]

# TODO: Verwende filter(..., lambda ...).
# Behalte nur Eintraege, die auf .txt enden.

# %% [markdown]
# ---
# ## 2. Rekursion-Basics
#
# ### 2.1 Countdown
# Schreibe `countdown(n)`, die `n, n-1, ... 1` ausgibt und dann `Start!`.
# Tipp: Was ist der einfachste Fall, bei dem die Funktion stoppen soll?

# %%
def countdown(n):
    # TODO: Basisfall und rekursiven Schritt einbauen.
    pass

countdown(4)

# %% [markdown]
# ### 2.2 Summe rekursiv
# Schreibe `summe_rekursiv(liste)`, die die Summe aller Elemente berechnet.
# Tipp: Die Liste wird bei jedem Aufruf kleiner.

# %%
def summe_rekursiv(liste):
    # TODO: Fall fuer leere Liste und Rueckgabe mit dem ersten Element.
    pass

print(summe_rekursiv([3, 5, 2]))
print(summe_rekursiv([]))

# %% [markdown]
# ### 2.3 Fakultaet rekursiv
# Schreibe `fakultaet(n)` fuer `n >= 0`.
# Tipp: Wann ist das Ergebnis sofort bekannt?

# %%
def fakultaet(n):
    # TODO: Basisfall und Rueckgabe mit n * fakultaet(n - 1).
    pass

print(fakultaet(0))
print(fakultaet(5))

# %% [markdown]
# ### 2.4 Wertsuche rekursiv
# Schreibe `enthaelt_wert(liste, ziel)` mit Rueckgabe `True/False`.
# Tipp: Zuerst pruefen, ob die Liste leer ist.

# %%
def enthaelt_wert(liste, ziel):
    # TODO: Basisfall und Vergleich mit dem ersten Element.
    pass

print(enthaelt_wert([10, 20, 30], 20))
print(enthaelt_wert([10, 20, 30], 99))

# %% [markdown]
# ---
# ## 3. Transfer
#
# ### 3.1 Rekursive Zeichenkette
# Schreibe `anzahl_zeichen(text, zeichen)`, die rekursiv zaehlt, wie oft `zeichen` in `text` vorkommt.
# Tipp: Der Text wird bei jedem Aufruf kuerzer.

# %%
def anzahl_zeichen(text, zeichen):
    # TODO: Leerer Text als Basisfall, sonst erstes Zeichen pruefen.
    pass

print(anzahl_zeichen("rekursion", "r"))
print(anzahl_zeichen("banana", "a"))
