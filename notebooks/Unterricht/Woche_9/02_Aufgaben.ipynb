# %% [markdown]
# # SW09 / KW46 - Aufgaben (Tuples + Dictionaries)
#
# Diese Aufgaben sind in drei Stufen aufgebaut:
# 1. **Gefuehrt**
# 2. **Teilweise gefuehrt**
# 3. **Transfer**
#
# Arbeite Schritt fuer Schritt und fuehre nach jedem Schritt die Code-Zelle aus.

# %% [markdown]
# ## Aufgabe 1 (geführt): Tuple-Grundlagen### Auftrag1. Erstelle ein Tuple `person` mit Name, Alter, Fach.2. Lies alle drei Werte mit Index aus und speichere sie in `name`, `alter`, `fach`.3. Entpacke ein Tuple `punkt = (4, 9)` in `x` und `y`.### Hinweise- Index startet bei `0` (erster Wert), `1` (zweiter Wert), `2` (dritter Wert).- Ein Tuple erkennt man an runden Klammern: `(wert1, wert2, wert3)`- Unpacking bedeutet: mehrere Variablen auf einmal aus dem Tuple füllen. Beispiel: `x, y = (1, 2)` bedeutet x=1, y=2.### Selbstcheck- Sind `name`, `alter`, `fach` korrekt gefüllt? (Überprüfe mit print())- Hat das Unpacking funktioniert? (x und y sollten 4 und 9 sein)

# %%
# TODO: Tuple erstellen# Schreibe ein Tuple mit: Name (String), Alter (Zahl), Fach (String)# Beispiel: ("Anna", 19, "Informatik")person = ()# TODO: Mit Index auslesen# Index 0 = erster Wert, Index 1 = zweiter, Index 2 = drittername = person[0]alter = person[1]fach = person[2]# TODO: Tuple entpacken# Statt person[0], person[1] direkt x, y aus dem Tuple auspackenpunkt = (4, 9)x, y = punkt# Überprüfung:print("Person:", name, ",", alter, "Jahre alt,", "Fach:", fach)print("Koordinaten: x =", x, ", y =", y)

# %% [markdown]
# ## Aufgabe 2 (geführt): Dictionary-Grundlagen### Auftrag1. Erstelle ein Dictionary `noten` mit mindestens zwei Schülern und ihren Noten.2. Lies eine Note per Key aus (wähle einen Schüler).3. Ändere eine vorhandene Note.4. Füge einen neuen Schüler hinzu.5. Gib alle Key-Value-Paare mit `.items()` aus.### Hinweise- Form: `{"Name": note}` mit geschweiften Klammern- Lesen: `noten["Name"]` gibt die Note zurück- Ändern: `noten["Name"] = neue_note` überschreibt die Note- Hinzufügen: `noten["Neuer_Name"] = note` fügt einen neuen Eintrag ein- Iteration: `for schueler, note in dict.items():` iteriert über alle Paare### Selbstcheck- Wurden alle 5 Anforderungen erfüllt?- Werden alle Schüler in der Ausgabe angezeigt?

# %%
# TODO: Dictionary erstellen# Schreibe mindestens 2 Schüler mit ihren Notennoten = {}# TODO: Note auslesen# Wähle einen Schüler (z. B. den ersten) und lies seine Noteprint("Ausgelesene Note:", noten["???"])  # Ersetze ??? mit einem Namen# TODO: Note anpassen und neuen Eintrag hinzufügen# Ändere eine bestehende Notenoten["???"] = ???# Füge einen neuen Schüler hinzunoten["???"] = ???# TODO: über alle Einträge iterierenprint("\nAlle Noten:")for schueler, note in noten.items():    print(schueler, "->", note)

# %% [markdown]
# ## Projektaufgabe: Rechnung als JSON
#
# Erstellt das verschachtelte Rechnungs-Dictionary mit den Schlüsseln `rechnungsnummer`, `datum`, `kunde`, `positionen` und `summen` (inklusive `mwst`). Fügt eine Position hinzu, ändert deren Menge, lest den Kundennamen aus und exportiert die vollständige Rechnung mit `json.dumps`. Prüft sie anschließend mit `json.loads`.

# %% [markdown]
# ## Aufgabe 3 (teilweise gefuehrt): Dictionary umkehren
#
# ### Auftrag
# Schreibe eine Funktion, die ein Dictionary umkehrt: aus `key -> value` wird
# `value -> key`.
#
# Beispiel: `{"a": 1} -> {1: "a"}`
#
# ### Hinweise
# - Du kannst davon ausgehen, dass alle Values eindeutig und hashable sind.
# - Nutze eine Schleife ueber `.items()`.
#
# ### Selbstcheck
# - Sind in der Ausgabe die Keys und Values vertauscht?

# %%
def dictionary_umkehren(dictionary):
    neuer_dictionary = {}
    # TODO: key/value vertauscht eintragen
    return neuer_dictionary


print(dictionary_umkehren({"a": 1, "b": 2}))

# %% [markdown]
# ## Aufgabe 4 (teilweise gefuehrt): Login-System mit Scaffolding### AuftragSchreibe eine Funktion `login(logins, eingabe_user, eingabe_passwort)`, die`True` zurückgibt, wenn Benutzername existiert und Passwort korrekt ist,sonst `False`.**Schritt für Schritt:**1. Schritt (Verständnis): Prüfe, ob ein Benutzer im Dictionary existiert2. Schritt (Logik): Vergleiche das gespeicherte Passwort mit der Eingabe3. Schritt (Integration): Kombiniere beide Checks in einer Funktion### Hinweise- Um zu prüfen, ob ein Key existiert: `if schluessel in dictionary:`- Um den Wert zu lesen: `dictionary[schluessel]`- Vergleiche Passwörter mit `==`### Selbstcheck- Unbekannter User → `False`- Falsches Passwort → `False`- Richtiger User und Passwort → `True`

# %%
# Schritt 1: Prüfe, ob der User existiertlogins = {"user1": "passwort1", "user2": "passwort2"}eingabe_user = "user1"# Ändere user1 zu user3, um zu sehen, was passiert:if eingabe_user in logins:    print("Benutzer gefunden!")else:    print("Benutzer nicht gefunden!")# Schritt 2: Wenn der User existiert, vergleiche das Passworteingabe_passwort = "passwort1"gespeichertes_passwort = logins[eingabe_user]if gespeichertes_passwort == eingabe_passwort:    print("Passwort korrekt!")else:    print("Passwort falsch!")# Schritt 3: Jetzt beide Checks kombinierendef login(logins, eingabe_user, eingabe_passwort):    # Check 1: Existiert der User?    if eingabe_user not in logins:        return False        # Check 2: Passwort korrekt?    if logins[eingabe_user] == eingabe_passwort:        return True    else:        return False        # Kurze Version (optional):    # return eingabe_user in logins and logins[eingabe_user] == eingabe_passwort# Teste die Funktion:print("\n=== Test ===")print(login({"user1": "passwort1", "user2": "passwort2"}, "user1", "passwort1"))  # Trueprint(login({"user1": "passwort1", "user2": "passwort2"}, "user3", "passwort1"))  # Falseprint(login({"user1": "passwort1", "user2": "passwort2"}, "user1", "falsch"))    # False

# %% [markdown]
# ## Aufgabe 5 (Transfer): Wort-Frequenzen
#
# ### Auftrag
# Schreibe eine Funktion `word_freq(text)`, die fuer jedes Wort in einem String
# zaehlt, wie oft es vorkommt.
#
# Beispiel: `"Hallo Welt hallo" -> {"Hallo": 1, "Welt": 1, "hallo": 1}`
#
# ### Hinweise
# - Zerlege den Text mit `split()`.
# - Nutze ein Dictionary als Zaehler.
#
# ### Selbstcheck
# - Werden wiederholte Woerter hochgezaehlt?
# - Funktioniert es auch bei leerem String?

# %%
def word_freq(text):
    # TODO: Dictionary mit Worthaeufigkeiten bauen
    return {}


print(word_freq("This is a simple example. This is a test example."))

# %% [markdown]
# ## Abschluss-Check
# - [ ] Ich kann ein Tuple erstellen und entpacken.
# - [ ] Ich kann ein Dictionary lesen, aendern und erweitern.
# - [ ] Ich kann mit `.items()` ueber Key-Value-Paare iterieren.
# - [ ] Ich kann eine Funktion mit Dictionary-Logik selbst schreiben.
#
# Wenn etwas unklar bleibt: Aufgaben 1 und 2 nochmals ohne Vorlage loesen.
