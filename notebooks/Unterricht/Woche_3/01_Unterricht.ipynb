# %% [markdown]
# # SW03 / KW40 - Bedingungen mit if / elif / else
#
# ## Einführung
# In dieser Woche steuert ihr Programme mit Bedingungen und trefft Entscheidungen im Code.
# Ihr lernt, wie unterschiedliche Eingaben zu unterschiedlichen Programmpfaden fuehren.
# Am Ende koennt ihr Entscheidungslogik klar formulieren und in Python umsetzen.
#
# Bevor wir loslegen, denkt an Bedingungen als Ja/Nein-Fragen:
# - "Ist die Zahl groesser als 5?"
# - "Ist der Benutzername korrekt?"
# - "Ist das Alter klein genug?"
#
# Ein `if`-Statement prueft genau solche Fragen. Wenn die Antwort "Ja" ist, wird ein bestimmter Codeblock ausgefuehrt. Wenn die Antwort "Nein" ist, wird ein anderer Weg gewaehlt oder der Code wird uebersprungen.
#
# Einfach gesagt:
# ```text
# Bedingung?
#   -> ja: mache A
#   -> nein: mache B oder tue nichts
# ```
#
# ## Lernziele dieser Woche
# - if-, elif- und else-Bloecke syntaktisch korrekt schreiben.
# - Boolesche Bedingungen mit Vergleichsoperatoren praezise formulieren.
# - Mehrstufige Entscheidungen in nachvollziehbare Programmlogik ueberfuehren.
# - Einfache Entscheidungsprogramme mit Testfaellen validieren.
#
# ## Rueckblick / Baut auf
# - Baut auf Woche 2 auf: Datentypen, Variablen und grundlegende Operationen.
# - Die hier eingefuehrte Entscheidungslogik wird fuer Schleifen und Fehlerbehandlung weiterverwendet.
#
# ## Ablauf der Lektion
# 1. Grundmuster von if/elif/else verstehen.
# 2. Bedingungen mit Beispielen analysieren.
# 3. Mehrstufige Entscheidungen programmieren.
# 4. Loesungen mit verschiedenen Eingaben testen.

# %% [markdown]
# ## 1. `if`/`else`
#
# ### 1.1 Ein erstes `if`-Statement
# Wenn wir in einem Programm etwas nur unter einer bestimmten Bedingungen ausführen wollen, verwenden wir dazu ein `if`-Statement. Ein `if`-Statement sieht wie folgt aus:

# %%
a = 2
b = 5

c = 5
d = 5
if a == b:
    print("Beide Zahlen sind gleich")
    print("...")

print("Wird in jedem Fall ausgeführt.")

# %% [markdown]
# Das `print`-Statement wird nur ausgeführt, wenn beide Zahlen gleich sind. Ansonsten wird dieser Code-Teil übersprungen.
#
# Schauen wir uns das `if`-Statement genauer an.
#
# 1. Auf der ersten Zeile steht `if`, gefolgt von einer Bedingung, gefolgt von einem Doppelpunkt. In diesem Fall ist die Bedingung `a == b` - also ob a und b gleich sind (Python verwendet zwei `==` für die Überprüfung, da ein einzelnes `=` bereits für die Variablenzuweisung reserviert ist).
# 2. Anschliessend kommen eine oder mehrere Code-Zeilen, welche nur ausgeführt werden, wenn die Bedingung erfüllt war. Diese Zeilen sind weiter eingerückt als der "normale" Code.
# 3. Sobald der `if`-Block beendet ist, schreiben wir wieder Code, der eingerückt ist wie zuvor. Dieser Code wird in jedem Fall ausgeführt.

# %% [markdown]
# ### Mini-Trace
# Schau dir dieses kleine Programm an und uebe zuerst, was das Programm macht, bevor du es ausfuehrst:
#
# ```python
# x = 4
# if x > 3:
#     print("x ist groesser als 3")
# print("fertig")
# ```
#
# - Was wird zuerst geprueft?
# - Welche Zeile wird nur ausgefuehrt, wenn die Bedingung wahr ist?
# - Was passiert danach immer?

# %% [markdown]
# Hier ist ein weiteres Beispielprogramm, welches ein `if`-Statement enthält. Kannst du voraussagen, was es macht?

# %%
mein_tier = "blauwal"
geraten = input("An welches Tier denke ich?")

if mein_tier == geraten:
    print("Richtig!")

print("Spielende.")

# %% [markdown]
# ### 1.2 `else`
# Wenn wir, falls die Bedingung nicht zutrifft, etwas anderes ausfuehren wollen, verwenden wir dazu `else` (auf Deutsch: "sonst"). Damit koennen wir das vorangehende Spiel wie folgt erweitern:
#
# Bis jetzt hatten wir zwei Wege: "wenn die Bedingung wahr ist" oder "wenn sie falsch ist". Mit `else` beschreiben wir genau diesen zweiten Weg. So wird aus einer Entscheidung etwas wie: "Wenn ja, dann mache A; sonst mache B".

# %%
mein_tier = "blauwal"
geraten = input("An welches Tier denke ich?")

if mein_tier == geraten:
    print("Richtig!")
else:
    print("Leider falsch...")

print("Spielende.")

# %% [markdown]
# Die Zeile `print("Leider falsch...")` wird nur ausgefuehrt, wenn das falsche Tier geraten wurde.
#
# Diese Form ist leicht zu lesen:
# - wenn die Bedingung erfuellt ist -> mache den ersten Block
# - sonst -> mache den zweiten Block
#
# Wenn ihr mehrere Entscheidungen hintereinander pruefen wollt, kommt spaeter `elif` dazu. Dann koennen Programme nicht nur "ja/nein", sondern auch "erster Fall", "zweiter Fall" oder "sonst" entscheiden.
#
# ### 1.3 `elif`
# Falls wir mehrere unterschiedliche Bedingungen ueberpruefen wollen, koennen wir dies mit `elif` (kurz fuer "else if", also "sonst wenn") tun. Im nachfolgenden Beispiel verwenden wir < und > um zu ueberpruefen, ob die erste Variable groesser oder kleiner als die Zweite ist.

# %%
a = 5
b = 5

if a > b:
    print("a ist grösser als b")
elif a < b:
    print("a ist kleiner als b")
else:
    print("a ist gleich b")

# %% [markdown]
# ### 1.4 Verschachtelte `if`-Statements
# In einem `if`-Block können wir weitere `if`-Statements ausführen, und so komplexe Logiken bilden. Hier ein Beispiel: Verstehst du, was das Programm macht?

# %%
username = "theuser"
password = "thepassword"

username_input = input("User?")
password_input = input("Passwort?")

if username == username_input:
    if password == password_input:
        print("Login erfolgreich.")
    else:
        print("Passwort falsch.")

else:
    print("User nicht bekannt.")

# %% [markdown]
# <div class="exercise">
#
# <img src="https://i.imgur.com/JyhBeDB.png" class="exercise_image" width=100>
#
# <span class="exercise_label">**Aufgabe:**</span>
#
# Schaue dir folgendes Programm an und gehe es Schritt fuer Schritt durch.
# - Schreibe zuerst auf, welche Bedingung an jeder Stelle geprueft wird.
# - Ueberlege dann, welche Ausgabe das Programm bei den folgenden Werten erzeugt:
#   - a) `b = 3`
#   - b) `b = 5`
#   - c) `b = 5` und `c = 8`
# - Vergleiche deine Vorhersage dann mit der Ausfuehrung im Notebook.
# ```python
# a = 3
# b = 5
# c = 3
#
# if a == b:
#     print("a ist gleich b")
# else:
#     if a == c:
#         print("a ist gleich c")
#     else:
#         if b == c:
#             print("b ist gleich b")
#         else:
#             print("Alle Zahlen sind unterschiedlich.")
#
# ```
#
# </div>

# %%
a = 3
b = 5
c = 8

if a == b:
    print("a ist gleich b")
elif a == c:
    print("a ist gleich c")
elif b == c:
    print("b ist gleich b")
else:
    print("Alle Zahlen sind unterschiedlich.")

# %% [markdown]
# ## 2. Bedingungen
#
# Wir haben gesehen, wie wir in `if`-Statements auf unterschiedliche Bedingungen reagieren können. Bis jetzt haben wir nur die Bedingung `==` (ist gleich) gesehen, es gibt aber noch andere Bedingungen. Diese schauen wir in diesem Kapitel an. Solche "Bedingungen" werden auch "Vergleichsoperationen" genannt.
# ### 2.1 Vergleichsoperationen
#
# Mit Vergleichsoperationen kann man zwei Werte vergleichen. Um zu vergleichen, ob zwei Objekte den gleichen Wert enthalten, haben wir "gleich" und "ungleich":
#
# - `==`: "gleich"
# - `!=`: "ungleich"

# %%
a = 10
b = 10
a == b

# %% [markdown]
# Wenn die Bedingung erfüllt ist, gibt die Operation "True" zurück. Ansonsten "False":

# %%
a = 10
b = 9
a == b

# %% [markdown]
# "Ungleich" ist das Gegenteil von "gleich":

# %%
a != b

# %% [markdown]
# Wir können `==` und `!=` auch für den Vergleich von Texten anwenden:

# %%
text1 = "hallo"
text2 = "hallo "
text1 == text2

# %% [markdown]
# Wenn wir aber Texte mit Zahlen vergleichen wollen, gibt `==` den Wert `False` zurück - auch wenn die Zahl dieselbe ist:

# %%
"1" == 1

# %% [markdown]
# Sobald auch nur ein Zeichen unterschiedlich ist, werden die Texte nicht mehr als gleich angesehen.

# %% [markdown]
# Für Zahlen können wir vergleichen, welcher Wert grösser ist. Dazu haben wir folgende Operationen:
# - `<=`: "kleiner gleich"
# - `<`: "kleiner"
# - `>`: "grösser"
# - `>=`: "grösser gleich"

# %%
a = 3
b = 2

a > b

# %%
a < b

# %% [markdown]
# Der Unterschied zwischen `>=` und `>` zeigt sich, wenn beide Werte gleich sind. In diesem Fall wird `>=` `True`, und `>` `False` zurückgeben.

# %%
a = 5
b = 5

a >= b

# %%
a > b

# %% [markdown]
# Für Texte haben wir einen anderen speziellen Operator: `in`. Damit können wir vergleichen, ob ein Text in einem anderen enthalten ist:

# %%
text1 = "Wort"
text2 = "Text2 enthält das Wort"
text3 = "Text3 nicht"

# %%
text1 in text2

# %%
text1 in text3

# %% [markdown]
# ### 2.2 Datentyp `bool`
#
# Wir haben gesehen, dass Vergleichsoperationen immer `True` oder `False` zurückgeben. Dafür gibt es einen speziellen Datentyp, sogenannte booleansche Variablen, oder kurz `bool`.

# %%
a = 3
b = 5

# Wir können das Resultat eines Vergleiches auch wieder als Variable abspeichern:
a_ist_grösser = a > b

# Wenn wir anschauen, was a_ist_grösser für einen Datentyp hat:
print("Datentyp:", type(a_ist_grösser))
print("Wert:", a_ist_grösser)

# %% [markdown]
# Wir können direkt Variablen mit einem boolschen Wert definieren:

# %%
is_it_good = True #Wichtig, Grosses T bzw. F (fuer False) 
type(is_it_good)

# %% [markdown]
# ### 2.3 Logische Operationen
# Wenn wir mehrere Bedingungen vergleichen wollen, können wir dies mit logischen Operationen machen. Es gibt drei logische Operationen:
#
# - `and`
# - `or`
# - `not`

# %% [markdown]
# Bei `and` überprüfen wir, ob beide Kriterien erfüllt sind. Bei `or` überprüfen wir, ob mindestens eines der Kriterien erfüllt ist. Und mit `not` können wir ein Kriterium umkehren.
#
# Damit können wir unser Login von vorher deutlich vereinfachen: Statt mit verschachtelten `if`-Statements mehrere Bedingungen zu überprüfen, können wir `and` verwenden:

# %%
# Wir definieren die "richtigen" Nutzerdaten im Code
nutzername = "nutzer123"
passwort = "hallo123"

# Dann fragen wir den/die Nutzer:in nach ihrem Login:
eingabe_nutzer = input("Was ist dein Nutzername?")
eingabe_passwort = input("Was ist dein Passwort?")

# Wir überprüfen nun mit and, ob beide Eingaben richtig sind
if nutzername == eingabe_nutzer and passwort == eingabe_passwort:
    print("Login erfolgreich.")
else:
    print("Login fehlgeschlagen.")

# %% [markdown]
# Das Programm von oben schreibt nur "Login erfolgreich", wenn sowohl Nutzername als auch Passwort stimmen.

# %% [markdown]
# <div class="exercise">
#
# <img src="https://i.imgur.com/JyhBeDB.png" class="exercise_image" width=100>
#
# <span class="exercise_label">**Aufgabe:**</span>
#
# Schaue dir folgendes Programm an und teste es mit drei kleinen Inputs.
# - Schritt 1: Teste `guess = "7"` und notiere die Ausgabe.
# - Schritt 2: Teste `guess = "3"` und notiere die Ausgabe.
# - Schritt 3: Teste `guess = "12"`. Was passiert?
# - Bonus: Welche Bedingung ist fuer den Fehlerfall wichtig?
# ```python
#
# print("Rate eine Zahl zwischen 1 und 10")
# guess = input()
# guess_nbr = int(guess)
#
# correct = 7
#
# if guess_nbr == correct:
#     print("Richtig, gratuliere!")
# elif guess_nbr < 1 or guess_nbr > 10:
#     print("Die Zahl muss zwischen 1 und 10 sein!")
# else:
#     print("Leider falsch")
# ```
#
# </div>

# %%
print("Rate eine Zahl zwischen 1 und 10")
guess = input()
guess_nbr = int(guess)

correct = 7

if guess_nbr == correct:
    print("Richtig, gratuliere!")
elif guess_nbr < 1 or guess_nbr > 10:
    print("Die Zahl muss zwischen 1 und 10 sein!")
else:
    print("Leider falsch")

# %% [markdown]
# <div class="exercise">
#
# <img src="https://i.imgur.com/JyhBeDB.png" class="exercise_image" width=100>
#
# <span class="exercise_label">**Aufgabe:**</span>
#
# Schriebe ein Programm fuer einen Quartierladen.
# - Schritt 1: Frage den/die Benutzer:in nach dem Alter.
# - Schritt 2: Pruefe zuerst die kleinste Bedingung (Alter < 16).
# - Schritt 3: Pruefe danach die mittlere Bedingung und zuletzt den letzten Fall.
# - Tipp: Was soll das Programm ausgeben, wenn das Alter genau 16 ist?
#
# </div>
