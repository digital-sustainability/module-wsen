# %% [markdown]
# # 1. Textverkettung
#
# Du hast nachfolgende Variablen. Füge sie zu einer neuen Variable `satz` zusammen.

# %%
wort1 = "Heute"
wort2 = "ist"
wort3 = "es"
wort4 = 30
wort5 = "Grad"
wort6 = "heiss"

# %%
print(wort1, wort2, wort3, wort4, wort5, wort6)
# Out:
# Heute ist es 30 Grad heiss

# %%
satz = wort1 + " " + wort2 +" " +wort3 + " " + str(wort4) + " " + wort5 + " " + wort6
satz
# Out:
# 'Heute ist es 30 Grad heiss'

# %% [markdown]
# # 2. Funktionsaufrufe
# Für folgende drei Funktionsaufrufe, beantworte folgende Fragen:
# - Welches sind die Argumente
# - Wird etwas zurückgegeben? Wenn ja, was?
#
# ```python
# print("hallo", "welt")
# float("3.15")
# input()
# ```

# %% [markdown]
# - Alles in Klammern sind die Argumente
# - Ja, es werden folgende Resultate ausgegeben: hallo welt, 3.15, alles was oben eingetragen wird

# %%
print("hallo", "welt")
# Out:
# hallo welt

# %%
float("3.15")
# Out:
# 3.15

# %%
input()
# Out:
# 'Ich habe Hunger'

# %% [markdown]
# # 3. Datentypen und Verarbeitung
#
# Sind folgende Ausdrücke zulässig? Was ist das Resultat? Welcher Datentyp hat das Resultat?
#
# ```python
# 3.15 + str(5.2)
# int(1.2 + 0.9)
# int("hallo" + "welt")
# float("3" + "." + "14")
# ```

# %% [markdown]
# - Nicht zulässig
# - zulässig, Resultat: 2, Datentyp: int
# - Nicht zulässig
# - zulässig, Resultat: 3.15, Datentyp: float

# %%
3.15 + str(5.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 3.15 + str(5.2)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
int(1.2 + 0.9)
# Out:
# 2

# %%
int("hallo" + "welt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int("hallo" + "welt")
#
# ValueError: invalid literal for int() with base 10: 'hallowelt'

# %%
float("3" + "." + "14")
# Out:
# 3.14

# %% [markdown]
# # 4. Fehlermeldungen verstehen
#
# Wir haben bereits unterschiedliche Fehlermeldungen gesehen. Es ist sehr wichtig, diese zu verstehen, um ein eigenes Programm schreiben zu können. Erkläre alle nachfolgenden Fehlermeldungen und finde ein Beispiel dazu.
#
# ```
# - SyntaxError: invalid syntax
# - IndentationError: unexpected indent
# - NameError: name 'abc' is not defined
# - ValueError: invalid literal for int() with base 10: 'abc'
# ```
