# %% [markdown]
# # SW11 / KW48 - Aufgaben: Vererbung
#
# ## Hinweise
# - Loese die Aufgaben in Reihenfolge.
# - Starte mit dem Verstehen: Wer ist Elternklasse, wer Kindklasse?
# - Teste jede Klasse direkt mit eigenen Objekten.
# - Nutze `super()` dort, wo gemeinsame Logik wiederverwendet werden soll.

# %% [markdown]
# ---
# ## 1. Eltern- und Kindklasse erkennen
#
# ### 1.1 Fahrzeug und Auto
# Erstelle eine Klasse `Fahrzeug` mit den Attributen `marke` und `tempo` sowie der Methode `beschreibung()`.
# Erstelle danach `Auto(Fahrzeug)` mit einer eigenen Methode `hupe()`.
#
# Frage: Was wird von `Fahrzeug` geerbt, und was ist neu in `Auto`?

# %%
# Aufgabe 1.1

# TODO: Fahrzeug implementieren

# TODO: Auto(Fahrzeug) implementieren

# Beispieltest
# a = Auto("Volvo", 120)
# print(a.beschreibung())
# print(a.hupe())

# %% [markdown]
# ### 1.2 Velo als einfache Erweiterung
# Erstelle `Velo(Fahrzeug)` mit dem zusaetzlichen Attribut `gaenge`.
# Achte darauf, dass die Elternlogik nicht doppelt geschrieben wird.

# %%
# Aufgabe 1.2

# TODO: Velo(Fahrzeug) implementieren

# Beispieltest
# v = Velo("BMC", 30, 12)
# print(v.beschreibung())
# print(v.gaenge)

# %% [markdown]
# ---
# ## 2. `super()` in Konstruktoren und Methoden
#
# ### 2.1 Person und Student
# Erstelle `Person` mit `name` und `alter`.
# Erstelle `Student(Person)` mit zusaetzlichem Attribut `studiengang`.
# Nutze `super().__init__(...)` im Konstruktor von `Student`.

# %%
# Aufgabe 2.1

# TODO: Person implementieren

# TODO: Student(Person) implementieren

# Beispieltest
# s = Student("Lea", 22, "Wirtschaftsinformatik")
# print(s.name, s.alter, s.studiengang)

# %% [markdown]
# ### 2.2 Vorstellen erweitern
# Ergaenze in `Person` eine Methode `vorstellen()`.
# Ueberschreibe sie in `Student`, rufe aber zuerst die Elternmethode auf und ergaenze den Studiengang.
#
# Mini-Check: Welche Zeile ist die Elternlogik, welche Zeile ist die Erweiterung?

# %%
# Aufgabe 2.2

# TODO: Methode vorstellen() in Person und Student implementieren

# Beispieltest
# print(s.vorstellen())

# %% [markdown]
# ---
# ## 3. Ergaenzen oder ueberschreiben
#
# ### 3.1 Bus als Spezialisierung
# Erstelle `Bus(Fahrzeug)` mit dem zusaetzlichen Attribut `plaetze`.
# Entscheide bewusst: Soll `beschreibung()` die Elternausgabe erweitern oder komplett ersetzen?

# %%
# Aufgabe 3.1

# TODO: Bus(Fahrzeug) implementieren

# Beispieltest
# b = Bus("MAN", 90, 52)
# print(b.beschreibung())

# %% [markdown]
# ### 3.2 Schulpersonen-Hierarchie
# Erstelle `Lehrperson(Person)` mit dem zusaetzlichen Attribut `fach`.
# Ueberschreibe `vorstellen()` so, dass zuerst die Elternlogik und dann das Fach ausgegeben wird.

# %%
# Aufgabe 3.2

# TODO: Lehrperson(Person) implementieren

# Beispieltest
# lp = Lehrperson("Herr Meier", "Informatik")
# print(lp.vorstellen())

# %% [markdown]
# ## Projektaufgabe: Gutschrift modellieren
#
# Erstellt eine Basisklasse `Rechnung` mit gemeinsamer Nummer, Kunde und Positionen. Leitet `Gutschrift` ab und überschreibt die Betragsmethode so, dass der Gesamtbetrag negativ ist. Prüft, dass geerbte Attribute erhalten bleiben und die Ausgabe den Rechnungstyp nennt.
