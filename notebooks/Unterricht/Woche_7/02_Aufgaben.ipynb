# %% [markdown]
# # SW07 / KW44 - Aufgaben zur Fehlerbehandlung
#
# Die Aufgaben sind gestuft aufgebaut: von einfacher Exception-Behandlung bis zu einem kleinen Gesamtprogramm.

# %% [markdown]
# ## 1) Sicher rechnen
# Schreibe eine Funktion `calculate(number1, number2, operator)`.
#
# Anforderungen:
# - Unterstützt `+`, `-`, `*`, `/`
# - Bei unbekanntem Operator: `ValueError` auslösen
# - Division durch 0 wird **nicht** hier behandelt (später in `calculator`)
#
# Teste mit den folgenden Aufrufen:

# %%
def calculate(number1, number2, operator):
    pass

# %%
print(calculate(8, 2, "+"))
print(calculate(8, 2, "-"))
print(calculate(8, 2, "*"))
print(calculate(8, 2, "/"))
# print(calculate(8, 2, "mal"))  # Soll ValueError auslösen

# %% [markdown]
# ## 2) Zahl robust einlesen
# Schreibe `ask_for_number(ausgabetext)`, die so lange nach einer Zahl fragt, bis eine gültige Eingabe vorliegt.
#
# Hinweise:
# - Nutze `while True`.
# - Teste mit Eingaben wie `abc` oder `5x`, damit du siehst, wie die Funktion auf ungültige Eingaben reagiert.
# - Bei ungültiger Eingabe soll eine kurze, freundliche Meldung erscheinen.
# - Bei Erfolg soll eine `float` zurückgegeben werden.

# %%
def ask_for_number(ausgabetext):
    # Tipp: Frage wiederholt nach einer Zahl, bis float(eingabe) funktioniert.
    pass

# %% [markdown]
# ## 3) Projektaufgabe: sichere Rechnungseingabe
# Schreibe `validiere_rechnungsdaten(kunde_id, kunde_name, artikel_nummer, artikel_name, menge_input, einzelpreis_input, mwst_input)`.
#
# Anforderungen:
# - Prüfe Kunden- und Artikeldaten mit einfachen Bedingungen wie `if not kunde_name ...`.
# - Wandle `menge_input`, `einzelpreis_input` und `mwst_input` mit `try`/`except ValueError` in Zahlen um.
# - Akzeptiere nur positive Mengen, nichtnegative CHF-Preise und die MWST-Sätze `0.0`, `2.5`, `3.7` oder `7.7`.
# - Gib die validierten Daten als drei Tupel zurück: Kunde, Artikel und Position.
# - Teste einen gültigen und vier fehlerhafte Datensätze.

# %%
ERLAUBTE_MWST = (0.0, 2.5, 3.7, 7.7)

def validiere_rechnungsdaten(kunde_id, kunde_name, artikel_nummer, artikel_name, menge_input, einzelpreis_input, mwst_input):
    pass

# Eigene Tests:
# print(validiere_rechnungsdaten("K100", "Alpen Technik AG", "A200", "USB-C Kabel", "2", "12.5", "7.7"))

# %% [markdown]
# ## 4) Mini-Taschenrechner

# %%
def calculator():
    pass

# %%
# Teste interaktiv:
# calculator()

# %% [markdown]
# ## 5) ID-Text parsen mit Validierung
# Wir verwenden einen vereinfachten, maschinenlesbaren Text einer ID.
#
# Schreibe die Funktionen:
# 1. `whitespace_entfernen(text)`: entfernt Leerzeichen, Zeilenumbrüche und Tabs.
# 2. `id_nummer_lesen(id_text_ohne_ws)`: liest die 9-stellige Nummer direkt nach `IDCHE` und validiert sie.
#
# `id_nummer_lesen` soll bei ungültigem Format `ValueError` auslösen.

# %%
beispiel = """
IDCHE123412345<<<<<<<<<<<<<<<
MUSTER<<ANNA<MARIA<<<<<<<<<<
"""

# %%
def whitespace_entfernen(text):
    pass

def id_nummer_lesen(id_text_ohne_ws):
    pass

# %%
beispiel_ohne_ws = whitespace_entfernen(beispiel)
print(id_nummer_lesen(beispiel_ohne_ws))
# print(id_nummer_lesen("FALSCHER_TEXT"))  # Soll ValueError auslösen
