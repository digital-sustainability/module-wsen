# %% [markdown]
# # SW09 / KW46 - Aufgaben (Tuples + Dictionaries)
#
# Diese Aufgaben sind in drei Stufen aufgebaut:
# 1. **Gefuehrt**
# 2. **Teilweise gefuehrt**
# 3. **Transfer**
#
# Arbeite Schritt fuer Schritt und fuehre nach jedem Schritt die Code-Zelle aus.

# %% [markdown]
# ## Aufgabe 1 (gefuehrt): Tuple-Grundlagen
#
# ### Auftrag
# 1. Erstelle ein Tuple `person` mit Name, Alter, Fach.
# 2. Lies alle drei Werte mit Index aus und speichere sie in `name`, `alter`, `fach`.
# 3. Entpacke ein Tuple `punkt = (4, 9)` in `x` und `y`.
#
# ### Hinweise
# - Index startet bei `0`.
# - Ein Tuple erkennt man an runden Klammern.
#
# ### Selbstcheck
# - Sind `name`, `alter`, `fach` korrekt gefuellt?
# - Haben `x` und `y` die Werte `4` und `9`?

# %%
# TODO: Tuple erstellen
person = ()

# TODO: Mit Index auslesen
name = None
alter = None
fach = None

# TODO: Tuple entpacken
punkt = (4, 9)
x = None
y = None

print(name, alter, fach)
print(x, y)

# %% [markdown]
# ## Aufgabe 2 (gefuehrt): Dictionary-Grundlagen
#
# ### Auftrag
# 1. Erstelle ein Dictionary `noten` mit mindestens zwei Eintraegen.
# 2. Lies eine Note per Key aus.
# 3. Aendere eine vorhandene Note.
# 4. Fuege einen neuen Schueler hinzu.
# 5. Gib alle Key-Value-Paare mit `.items()` aus.
#
# ### Hinweise
# - Form: `{"Name": note}`
# - Iteration: `for key, value in dict.items():`
#
# ### Selbstcheck
# - Wurde ein bestehender Eintrag geaendert?
# - Ist ein neuer Eintrag dazugekommen?

# %%
# TODO: Dictionary erstellen
noten = {}

# TODO: Note auslesen
print("Ausgelesene Note:", None)

# TODO: Note anpassen und neuen Eintrag hinzufuegen

# TODO: ueber alle Eintraege iterieren
for schueler, note in noten.items():
    print(schueler, "->", note)

# %% [markdown]
# ## Aufgabe 3 (teilweise gefuehrt): Dictionary umkehren
#
# ### Auftrag
# Schreibe eine Funktion, die ein Dictionary umkehrt: aus `key -> value` wird
# `value -> key`.
#
# Beispiel: `{"a": 1} -> {1: "a"}`
#
# ### Hinweise
# - Du kannst davon ausgehen, dass alle Values eindeutig und hashable sind.
# - Nutze eine Schleife ueber `.items()`.
#
# ### Selbstcheck
# - Sind in der Ausgabe die Keys und Values vertauscht?

# %%
def dictionary_umkehren(dictionary):
    neuer_dictionary = {}
    # TODO: key/value vertauscht eintragen
    return neuer_dictionary


print(dictionary_umkehren({"a": 1, "b": 2}))

# %% [markdown]
# ## Aufgabe 4 (teilweise gefuehrt): Login-System
#
# ### Auftrag
# Schreibe eine Funktion `login(logins, eingabe_user, eingabe_passwort)`, die
# `True` zurueckgibt, wenn Benutzername existiert und Passwort korrekt ist,
# sonst `False`.
#
# ### Hinweise
# - Pruefe zuerst, ob der User im Dictionary vorhanden ist.
# - Vergleiche danach das gespeicherte Passwort.
#
# ### Selbstcheck
# - Unbekannter User -> `False`
# - Falsches Passwort -> `False`
# - Richtige Kombination -> `True`

# %%
def login(logins, eingabe_user, eingabe_passwort):
    # TODO: Logik ergaenzen
    return False


print(login({"user1": "passwort1", "user2": "passwort2"}, "user1", "passwort1"))
print(login({"user1": "passwort1", "user2": "passwort2"}, "user3", "passwort1"))
print(login({"user1": "passwort1", "user2": "passwort2"}, "user1", "passwort3"))

# %% [markdown]
# ## Aufgabe 5 (Transfer): Wort-Frequenzen
#
# ### Auftrag
# Schreibe eine Funktion `word_freq(text)`, die fuer jedes Wort in einem String
# zaehlt, wie oft es vorkommt.
#
# Beispiel: `"Hallo Welt hallo" -> {"Hallo": 1, "Welt": 1, "hallo": 1}`
#
# ### Hinweise
# - Zerlege den Text mit `split()`.
# - Nutze ein Dictionary als Zaehler.
#
# ### Selbstcheck
# - Werden wiederholte Woerter hochgezaehlt?
# - Funktioniert es auch bei leerem String?

# %%
def word_freq(text):
    # TODO: Dictionary mit Worthaeufigkeiten bauen
    return {}


print(word_freq("This is a simple example. This is a test example."))

# %% [markdown]
# ## Abschluss-Check
# - [ ] Ich kann ein Tuple erstellen und entpacken.
# - [ ] Ich kann ein Dictionary lesen, aendern und erweitern.
# - [ ] Ich kann mit `.items()` ueber Key-Value-Paare iterieren.
# - [ ] Ich kann eine Funktion mit Dictionary-Logik selbst schreiben.
#
# Wenn etwas unklar bleibt: Aufgaben 1 und 2 nochmals ohne Vorlage loesen.
