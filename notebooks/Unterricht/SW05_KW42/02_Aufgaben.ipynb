# %% [markdown]
# # SW05 / KW42 – Aufgaben
#
# ## Aufgabe 1 – Listen vorbereiten
# Erstelle eine Liste `products` mit mindestens 5 Dictionaries. Jedes Dictionary soll enthalten:
# - `id` (int)
# - `name` (str)
# - `preis` (float)
# - `lager` (int)

# %%
# TODO: products erstellen
products = []
products

# %% [markdown]
# ## Aufgabe 2 – Pandas nutzen
# 1. Erstelle aus `products` einen DataFrame `df_products`.
# 2. Berechne den durchschnittlichen Preis.
# 3. Filtere alle Produkte mit `lager < 10`.

# %%
import pandas as pd

# TODO: DataFrame erstellen und Auswertungen machen
df_products = pd.DataFrame(products)
df_products

# %% [markdown]
# ## Aufgabe 3 – Datenbankzugriff via Python
# 1. Erstelle eine SQLite In-Memory Datenbank.
# 2. Lege eine Tabelle `produkte` an.
# 3. Schreibe alle Zeilen aus `products` in die Tabelle.
# 4. Führe eine Query aus: alle Produkte mit `preis >= 20`, sortiert nach `preis` absteigend.
# 5. Speichere das Query-Resultat in `query_result`.

# %%
import sqlite3

# TODO: DB erstellen, Daten schreiben, Query ausführen
query_result = []
query_result

# %% [markdown]
# ## Aufgabe 4 – Integration
# Wandle `query_result` in einen DataFrame `df_query` um und gib ihn aus.

# %%
# TODO: query_result -> DataFrame
df_query = pd.DataFrame(query_result, columns=["id", "name", "preis", "lager"])
df_query
