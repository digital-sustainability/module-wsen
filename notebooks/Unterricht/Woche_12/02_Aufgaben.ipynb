# %% [markdown]
# # SW12 / KW49 - Aufgaben
# Themen: Comprehensions und String-Formatierung.

# %% [markdown]
# ## A) Comprehensions

# %% [markdown]
# ### Aufgabe 1
# Wandle die Schleife in eine List-Comprehension um (grossgeschriebene Namen).
# Tipp: Der Ausdruck für jedes Element ist `n.upper()`.

# %%
namen = ["anna", "ben", "cora"]
gross = []
for n in namen:
    gross.append(n.upper())

print(gross)

# %% [markdown]
# ### Aufgabe 2
# Erzeuge mit einer Comprehension eine Liste aller geraden Zahlen von 0 bis 20.
# Tipp: Du brauchst eine Bedingung, damit nur gerade Zahlen bleiben.

# %% [markdown]
# ### Aufgabe 3
# Erstelle ein Dictionary `laengen`, das jedem Wort seine Länge zuordnet.
# Tipp: Die Form ist `{schluessel: wert for ...}`.

# %%
woerter = ["python", "oop", "datenbank", "api"]

# %% [markdown]
# ### Aufgabe 4
# Finde und korrigiere den Fehler.
# Tipp: In einer Comprehension steht der Ausdruck für jedes Element direkt vor dem `for`.

# %%
werte = [2, 4, 6]
verdoppelt = [w * 2 in werte]
print(verdoppelt)

# %% [markdown]
# ## Projektaufgabe (Teil 1): Rechnungspositionen filtern mit Comprehensions
#
# Filtert aus dem SW9-Rechnungs-Dictionary mit einer List-Comprehension alle Positionen mit MWST-Satz 7.7 %.

# %% [markdown]
# ## B) String-Formatierung

# %% [markdown]
# ### Aufgabe 5
# Gib den Satz mit f-String aus: `Lea hat 14 Punkte erreicht.`
# Tipp: Nutze geschweifte Klammern für die Variablen.

# %%
name = "Lea"
punkte = 14

# %% [markdown]
# ### Aufgabe 6
# Formatiere die Zahl `3.1415926` auf 3 Nachkommastellen.
# Tipp: Der Format-Spezifizierer für drei Nachkommastellen ist `:.3f`.

# %% [markdown]
# ### Aufgabe 7
# Formatiere `0.256` als Prozent mit 1 Nachkommastelle.
# Tipp: Für Prozentzahlen nutzt man `:.1%`.

# %% [markdown]
# ### Aufgabe 8
# Nutze `.format(...)` mit benannten Platzhaltern für diesen Text:
# `Hallo {name}, Ihr Termin ist am {datum}`.
# Tipp: Ersetze die Platzhalter mit `name=` und `datum=`.

# %% [markdown]
# ## Projektaufgabe (Teil 2): Druckbare Rechnung und Exporte
#
# Erzeugt aus dem SW9-Dictionary eine Ausgabe mit Kopfzeile, Kundendaten, Positionstabelle, MWST-Aufstellung und Endbetrag. Nutzt f-Strings mit zwei Nachkommastellen. Gebt die Rechnung zusätzlich mit `json.dumps` sowie über `csv.DictWriter` als CSV aus; fehlende Bezeichnungen sollen nicht zum Absturz führen.

# %% [markdown]
# ## C) Transfer

# %% [markdown]
# ### Aufgabe 9
# Aus der Liste `preise` soll eine Liste von formatierten Texten entstehen, z.B. `Artikel 1: 4.50 CHF`.
# Tipp: Überlege zuerst, wie ein einzelner Text formatiert werden soll, und baue dann die komplette Liste auf.

# %%
preise = [4.5, 19, 0.99, 12.345]

# %% [markdown]
# ### Aufgabe 10
# Erzeuge aus `noten` ein Dictionary mit Status:
# - `bestanden`, wenn Note >= 4.0
# - sonst `nicht bestanden`
# Tipp: Arbeite zuerst mit einem einzelnen Paar `name, note` und baue dann die Comprehension auf.

# %%
noten = {"Ava": 5.0, "Liam": 3.5, "Mia": 4.0}
