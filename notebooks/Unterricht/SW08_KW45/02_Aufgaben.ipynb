# %% [markdown]
# # SW08 / KW45 - Aufgaben (OOP + BO/ERD)
#
# Diese Aufgaben sind in drei Stufen aufgebaut:
# 1. **Gefuehrt**
# 2. **Teilweise gefuehrt**
# 3. **Transfer**
#
# Arbeite Schritt fuer Schritt. Fuehre nach jedem Schritt die Zelle aus.

# %% [markdown]
# ## Aufgabe 1 (gefuehrt): Klasse `Produkt`
#
# ### Auftrag
# Erstelle eine Klasse `Produkt` mit:
# - Attributen `produkt_nr`, `name`, `preis`
# - Methode `rabatt_preis(prozent)`, die den reduzierten Preis zurueckgibt
#
# ### Hinweise
# - Prozent von 20 bedeutet 20%.
# - Formel: `preis * (1 - prozent / 100)`
#
# ### Selbstcheck
# - Ein Produkt mit Preis 50 hat bei 20% Rabatt den Wert 40.

# %%
class Produkt:
    def __init__(self, produkt_nr, name, preis):
        # TODO: Attribute setzen
        pass

    def rabatt_preis(self, prozent):
        # TODO: reduzierten Preis zurueckgeben
        pass

produkt = Produkt(10, "Maus", 50)
produkt.rabatt_preis(20)

# %% [markdown]
# ## Aufgabe 2 (teilweise gefuehrt): Klasse `Warenkorb`
#
# ### Auftrag
# Erstelle eine Klasse `Warenkorb` mit:
# - Attribut `produkte` (Liste)
# - Methode `produkt_hinzufuegen(produkt)`
# - Methode `gesamtpreis()`, die die Summe aller Produktpreise liefert
#
# ### Hinweise
# - Verwende in `__init__` eine leere Liste.
# - In `gesamtpreis()` kannst du ueber die Liste iterieren und summieren.
#
# ### Selbstcheck
# - Bei Preisen 30 und 45 muss `gesamtpreis()` den Wert 75 geben.

# %%
class Warenkorb:
    def __init__(self):
        # TODO
        pass

    def produkt_hinzufuegen(self, produkt):
        # TODO
        pass

    def gesamtpreis(self):
        # TODO
        pass

p1 = Produkt(1, "Tastatur", 30)
p2 = Produkt(2, "Headset", 45)

korb = Warenkorb()
korb.produkt_hinzufuegen(p1)
korb.produkt_hinzufuegen(p2)
korb.gesamtpreis()

# %% [markdown]
# ## Aufgabe 3 (Transfer): BO <-> ERD in Code umsetzen
#
# ### Szenario
# Ein `Kunde` kann mehrere `Bestellung`-Objekte haben (Beziehung 1:n).
#
# ### Auftrag
# 1. Erstelle Klasse `Bestellung` mit `bestell_nr` und `betrag`.
# 2. Erstelle Klasse `Kunde` mit `kunden_nr`, `name` und Liste `bestellungen`.
# 3. Erstelle Methode `bestellung_hinzufuegen(bestellung)` in `Kunde`.
# 4. Teste mit mindestens zwei Bestellungen.
#
# ### Selbstcheck
# - `len(kunde.bestellungen)` ist 2.
# - Du kannst die Bestellnummern ueber die Liste ausgeben.

# %%
class Bestellung:
    # TODO
    pass

class Kunde:
    # TODO
    pass

kunde = Kunde(7, "Lina")
kunde.bestellung_hinzufuegen(Bestellung(9001, 120))
kunde.bestellung_hinzufuegen(Bestellung(9002, 35))

len(kunde.bestellungen)

# %% [markdown]
# ## Abschluss-Check
# - [ ] Ich kann erklaeren, wo Klasse und Objekt im eigenen Code vorkommen.
# - [ ] Ich kann Attribute korrekt in `__init__` speichern.
# - [ ] Ich kann eine 1:n Beziehung mit einer Liste modellieren.
# - [ ] Ich kann mein Ergebnis mit kleinen Tests pruefen.
#
# Wenn etwas nicht klappt: zuerst Fehlermeldung lesen, dann mit `print(type(...))` und `print(...)` Zwischenschritte sichtbar machen.
